# %% [markdown]
# # Portfolio 3 - Clustering Visualisation

# %% [markdown]
# K-means clustering is one of the simplest and popular unsupervised learning algorithms. Typically, unsupervised algorithms make inferences from datasets using only input vectors without referring to known, or labelled, outcomes. This notebook illustrates the process of K-means clustering by generating some random clusters of data and then showing the iterations of the algorithm as random cluster means are updated.

# %% [markdown]
# We first generate random data around 4 centers.

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
center_1 = np.array([1,2])
center_2 = np.array([6,6])
center_3 = np.array([9,1])
center_4 = np.array([-5,-1])

# Generate random data and center it to the four centers each with a different variance
np.random.seed(5)
data_1 = np.random.randn(200,2) * 1.5 + center_1
data_2 = np.random.randn(200,2) * 1 + center_2
data_3 = np.random.randn(200,2) * 0.5 + center_3
data_4 = np.random.randn(200,2) * 0.8 + center_4

data = np.concatenate((data_1, data_2, data_3, data_4), axis = 0)

plt.scatter(data[:,0], data[:,1], s=7, c='k')
plt.show()

# %% [markdown]
# ## 1. Generate random cluster centres
#
# You need to generate four random centres.
#
# This part of portfolio should contain at least:
# - The number of clusters `k` is set to 4;
# - Generate random centres via `centres = np.random.randn(k,c)*std + mean` where `std` and `mean` are the standard deviation and mean of the data. `c` represents the number of features in the data. Set the random seed to 6.
# - Color the generated centers with `green`, `blue`, `yellow`, and `cyan`. Set the edgecolors to `red`.

# %%
np.random.seed(6)
std = np.std(data)
mean = np.mean(data)
K = 4
centres = np.random.randn(K,2)*std + mean
print(centres)

plt.scatter(data[:,0],data[:,1], s=7, c='k')
color=['y','g','b','c']
plt.scatter(centres[:,0], centres[:,1], s=70, c=color, edgecolor='r')
# Out:
# [[ 1.0430169   5.53863665]
#  [ 3.33061168 -1.4938254 ]
#  [-8.35175241  6.33448312]
#  [ 7.25803215 -4.15028729]]

# %% [markdown]
# ## 2. Visualise the clustering results in each iteration

# %% [markdown]
# You need to implement the process of k-means clustering.  Implement each iteration as a seperate cell, assigning each data point to the closest centre, then updating the cluster centres based on the data, then plot the new clusters.
#
# Replace this text with your explaination of the algorithm.  The resulting notebook should provide a good explanation and demonstration of the K-means algorithm.

# %%
import math


# helper function
def get_distance(p1, p2):
    distance = math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)
    return distance

def get_center_point(points):
    x = [p[0] for p in points]
    y = [p[1] for p in points]
    centroid = (sum(x) / len(points), sum(y) / len(points))
    return centroid

def k_means_onestep(data, centres):
    new_center = [[],[],[],[]]
    
    point_belone = [[] for i in range(K)]

    for p in data:
        distance = []
        distance.append(get_distance(centres[0], p))
        distance.append(get_distance(centres[1], p))
        distance.append(get_distance(centres[2], p))
        distance.append(get_distance(centres[3], p))
        idx = distance.index(min(distance))
        point_belone[idx].append(p)

        
    # update center point
    for c in range(len(point_belone)):
        new_center[c] = get_center_point(point_belone[c])
    
    return new_center, point_belone

# %%
center_point_step1, new_data = k_means_onestep(data, centres)
# print(center_point_step1)

# %%
for p1 in new_data[0]:
    plt.scatter(p1[0], p1[1], s=7, c=color[0])
    
for p2 in new_data[1]:
    plt.scatter(p2[0], p2[1], s=7, c=color[1])
    
for p3 in new_data[2]:
    plt.scatter(p3[0], p3[1], s=7, c=color[2])
    
for p4 in new_data[3]:
    plt.scatter(p4[0], p4[1], s=7, c=color[3])
    

plt.scatter(center_point_step1[0][0], center_point_step1[0][1], s=70, c=color[0], edgecolor='r')
plt.scatter(center_point_step1[1][0], center_point_step1[1][1], s=70, c=color[1], edgecolor='r')
plt.scatter(center_point_step1[2][0], center_point_step1[2][1], s=70, c=color[2], edgecolor='r')
plt.scatter(center_point_step1[3][0], center_point_step1[3][1], s=70, c=color[3], edgecolor='r')

# %%
center_point_step2, new_data2 = k_means_onestep(data, center_point_step1)
# print(center_point_step2)

# %%
for p1 in new_data2[0]:
    plt.scatter(p1[0], p1[1], s=7, c=color[0])
    
for p2 in new_data2[1]:
    plt.scatter(p2[0], p2[1], s=7, c=color[1])
    
for p3 in new_data2[2]:
    plt.scatter(p3[0], p3[1], s=7, c=color[2])
    
for p4 in new_data2[3]:
    plt.scatter(p4[0], p4[1], s=7, c=color[3])
    

plt.scatter(center_point_step2[0][0], center_point_step2[0][1], s=70, c=color[0], edgecolor='r')
plt.scatter(center_point_step2[1][0], center_point_step2[1][1], s=70, c=color[1], edgecolor='r')
plt.scatter(center_point_step2[2][0], center_point_step2[2][1], s=70, c=color[2], edgecolor='r')
plt.scatter(center_point_step2[3][0], center_point_step2[3][1], s=70, c=color[3], edgecolor='r')

# %%
center_point_step3, new_data3 = k_means_onestep(data, center_point_step2)
# print(center_point_step3)

for p1 in new_data3[0]:
    plt.scatter(p1[0], p1[1], s=7,c=color[0])
    
for p2 in new_data3[1]:
    plt.scatter(p2[0], p2[1], s=7,c=color[1])
    
for p3 in new_data3[2]:
    plt.scatter(p3[0], p3[1], s=7,c=color[2])
    
for p4 in new_data3[3]:
    plt.scatter(p4[0], p4[1], s=7,c=color[3])

plt.scatter(center_point_step3[0][0], center_point_step3[0][1], s=70, c=color[0], edgecolor='r')
plt.scatter(center_point_step3[1][0], center_point_step3[1][1], s=70, c=color[1], edgecolor='r')
plt.scatter(center_point_step3[2][0], center_point_step3[2][1], s=70, c=color[2], edgecolor='r')
plt.scatter(center_point_step3[3][0], center_point_step3[3][1], s=70, c=color[3], edgecolor='r')

# %%
center_point_step4, new_data4 = k_means_onestep(data, center_point_step3)
# print(center_point_step4)

for p1 in new_data4[0]:
    plt.scatter(p1[0], p1[1], s=7,c=color[0])
    
for p2 in new_data4[1]:
    plt.scatter(p2[0], p2[1], s=7, c=color[1])
    
for p3 in new_data4[2]:
    plt.scatter(p3[0], p3[1], s=7, c=color[2])
    
for p4 in new_data4[3]:
    plt.scatter(p4[0], p4[1], s=7, c=color[3])

plt.scatter(center_point_step4[0][0], center_point_step4[0][1], s=70, c=color[0], edgecolor='r')
plt.scatter(center_point_step4[1][0], center_point_step4[1][1], s=70, c=color[1], edgecolor='r')
plt.scatter(center_point_step4[2][0], center_point_step4[2][1], s=70, c=color[2], edgecolor='r')
plt.scatter(center_point_step4[3][0], center_point_step4[3][1], s=70, c=color[3], edgecolor='r')

# %%
center_point_step5, new_data5 = k_means_onestep(data, center_point_step4)
# print(center_point_step5)

for p1 in new_data5[0]:
    plt.scatter(p1[0], p1[1], s=7,c=color[0])
    
for p2 in new_data5[1]:
    plt.scatter(p2[0], p2[1], s=7,c=color[1])
    
for p3 in new_data5[2]:
    plt.scatter(p3[0], p3[1], s=7,c=color[2])
    
for p4 in new_data5[3]:
    plt.scatter(p4[0], p4[1], s=7,c=color[3])

plt.scatter(center_point_step5[0][0], center_point_step5[0][1], s=70, c=color[0], edgecolor='r')
plt.scatter(center_point_step5[1][0], center_point_step5[1][1], s=70, c=color[1], edgecolor='r')
plt.scatter(center_point_step5[2][0], center_point_step5[2][1], s=70, c=color[2], edgecolor='r')
plt.scatter(center_point_step5[3][0], center_point_step5[3][1], s=70, c=color[3], edgecolor='r')

# %%
print(center_point_step5[0])
print(center_point_step5[1])
print(center_point_step5[2])
print(center_point_step5[3])
# Out:
# (6.005329800270005, 5.925288654136424)
# (0.9829782540320567, 2.157879591298147)
# (-5.0571701392965585, -0.9496703076782568)
# (9.06363900230104, 1.0463390714865732)

# %%
## center_1 = np.array([1,2])
## center_2 = np.array([6,6])
## center_3 = np.array([9,1])
## center_4 = np.array([-5,-1])

# %% [markdown]
# ### Those centroids are quite close by comparing with initial centers. Hence, we can stop at step 5 as the last iteration.
